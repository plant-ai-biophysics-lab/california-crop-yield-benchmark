# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')

# %%
import geopandas as gpd
import plot_inf as util

# %%
gdf = gpd.read_file('/data2/hkaman/Data/Livingston/shp/Livingston_boundaries.shp')
gdf.iloc[3]['geometry']
# Out:
# <POLYGON ((-74226.809 -72994.451, -74036.969 -72996.536, -74046.974 -73382.0...>

# %%
ndvi, et, yield_map = util.disaggregate_yield_to_pixels(gdf.iloc[3]['geometry'], predicted_county_yield = 11.21)

# %%
util.plot_ndvi_et_yield(ndvi, et, yield_map)
